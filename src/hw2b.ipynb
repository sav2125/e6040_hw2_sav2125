# %% [markdown]
# # ECBM E6040 Homework 2 - Programming Problem

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from hw2b import load_data, LogisticRegression, HiddenLayer, MLP, test_mlp
import theano
import theano.tensor as T
sz = 5
for i in range(5):
    print i
# Out:
# 0
# 1
# 2
# 3
# 4
# Using gpu device 0: GRID K520

# %% [markdown]
# ### Bullet 2: Comparison between _tanh_ and _softmax_

# %%
# TODO
test_mlp(layer = 2, act_function = 1)
#tanh
test_mlp(layer = 2, act_function = 2)
#softmax
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 1318/1318, validation error 81.136986 %
#      epoch 1, minibatch 1318/1318, test error of best model 80.423077 %
# epoch 2, minibatch 1318/1318, validation error 80.986301 %
#      epoch 2, minibatch 1318/1318, test error of best model 80.242308 %
# epoch 3, minibatch 1318/1318, validation error 80.547945 %
#      epoch 3, minibatch 1318/1318, test error of best model 79.761538 %
# epoch 4, minibatch 1318/1318, validation error 73.575342 %
#      epoch 4, minibatch 1318/1318, test error of best model 72.930769 %
# epoch 5, minibatch 1318/1318, validation error 61.945205 %
#      epoch 5, minibatch 1318/1318, test error of best model 62.661538 %
# epoch 6, minibatch 1318/1318, validation error 55.013699 %
#      epoch 6, minibatch 1318/1318, test error of best model 56.273077 %
# epoch 7, minibatch 1318/1318, validation error 49.123288 %
# ...

# %%
test_mlp()
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 329/329, validation error 81.152778 %
#      epoch 1, minibatch 329/329, test error of best model 80.415385 %
# epoch 2, minibatch 329/329, validation error 81.152778 %
# epoch 3, minibatch 329/329, validation error 81.097222 %
#      epoch 3, minibatch 329/329, test error of best model 80.530769 %
# epoch 4, minibatch 329/329, validation error 80.416667 %
#      epoch 4, minibatch 329/329, test error of best model 80.480769 %
# epoch 5, minibatch 329/329, validation error 79.916667 %
#      epoch 5, minibatch 329/329, test error of best model 79.884615 %
# epoch 6, minibatch 329/329, validation error 79.222222 %
#      epoch 6, minibatch 329/329, test error of best model 79.061538 %
# epoch 7, minibatch 329/329, validation error 78.375000 %
#      epoch 7, minibatch 329/329, test error of best model 78.100000 %
# epoch 8, minibatch 329/329, validation error 77.388889 %
# ...

# %%
test_mlp(layer = 2, act_function = 2)
#softmax
# Out:
# ...
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 1318/1318, validation error 81.150685 %
#      epoch 1, minibatch 1318/1318, test error of best model 80.415385 %
# epoch 2, minibatch 1318/1318, validation error 81.150685 %
# epoch 3, minibatch 1318/1318, validation error 81.150685 %
# epoch 4, minibatch 1318/1318, validation error 81.150685 %
# epoch 5, minibatch 1318/1318, validation error 81.150685 %
# epoch 6, minibatch 1318/1318, validation error 81.150685 %
# epoch 7, minibatch 1318/1318, validation error 81.150685 %
# Optimization complete. Best validation score of 81.150685 % obtained at iteration 1318, with test performance 80.415385 %
# The code for file hw2b.py ran for 0.96m

# %%
### Bullet 3: Experiment with the number of hidden layers
### no of hidden layers varies from 1 to 8. toal layers varies from 3 to 10
test_performance = []
for i in range(1,9):
    test_per = test_mlp(layer = i, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.001, n_epochs=300,
             batch_size=100, n_hidden=300, verbose=True)
    test_performance.append(test_per)
    
    #test_per = test_mlp(layer = 3, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=300,
     #        batch_size=50, n_hidden=300, verbose=True)
    #print ("test accuracy in % is ", test_per)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 659/659, validation error 81.150685 %
#      epoch 1, minibatch 659/659, test error of best model 80.415385 %
# epoch 2, minibatch 659/659, validation error 81.068493 %
#      epoch 2, minibatch 659/659, test error of best model 80.376923 %
# epoch 3, minibatch 659/659, validation error 80.561644 %
#      epoch 3, minibatch 659/659, test error of best model 80.146154 %
# epoch 4, minibatch 659/659, validation error 79.904110 %
#      epoch 4, minibatch 659/659, test error of best model 79.688462 %
# epoch 5, minibatch 659/659, validation error 79.273973 %
#      epoch 5, minibatch 659/659, test error of best model 79.153846 %
# epoch 6, minibatch 659/659, validation error 78.315068 %
#      epoch 6, minibatch 659/659, test error of best model 78.157692 %
# epoch 7, minibatch 659/659, validation error 77.178082 %
#      epoch 7, minibatch 659/659, test error of best model 76.988462 %
# ...

# %%
for i in range(0,8):
    test_performance[i] = 100 -test_performance[i]*100
    print test_performance[i]
# Out:
# 77.4153846154
# 77.6384615385
# 82.6153846154
# 82.85
# 81.9076923077
# 82.1153846154
# 81.6615384615
# 82.3192307692

# %%
x3 = [1,2,3,4,5,6,7,8]
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x3,test_performance)

plt.show()

# %%
    test_per = test_mlp(layer = i, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=10,
             batch_size=200, n_hidden=500, verbose=True)
    print 'test accuracy is ' 
    print test_per
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 1318/1318, validation error 81.150685 %
#      epoch 1, minibatch 1318/1318, test error of best model 80.419231 %
# Optimization complete. Best validation score of 81.150685 % obtained at iteration 1318, with test performance 80.419231 %
# test accuracy is
# 0.804192307692
# The code for file hw2b.py ran for 0.10m

# %%
# TODO
for i in range(0,8):
    print test_performance[i]
# Out:
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# Plot the result (reproducing Figure 1)

# %%
# TODO

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %%
# TODO

# %% [markdown]
# ### Bullet 4: Experiment with the number of hidden layers, but fix the total number of neurons

# %%
# TODO
test_performance_part4 = []
for i in range(1,9):
    test_per = test_mlp(layer = i, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.001, n_epochs=1000,
             batch_size=100, n_hidden=int (2400/i), verbose=True)
    test_performance_part4.append(test_per)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 659/659, validation error 81.082192 %
#      epoch 1, minibatch 659/659, test error of best model 80.369231 %
# epoch 2, minibatch 659/659, validation error 80.438356 %
#      epoch 2, minibatch 659/659, test error of best model 79.857692 %
# epoch 3, minibatch 659/659, validation error 79.219178 %
#      epoch 3, minibatch 659/659, test error of best model 79.015385 %
# epoch 4, minibatch 659/659, validation error 78.342466 %
#      epoch 4, minibatch 659/659, test error of best model 78.334615 %
# epoch 5, minibatch 659/659, validation error 77.767123 %
#      epoch 5, minibatch 659/659, test error of best model 77.607692 %
# epoch 6, minibatch 659/659, validation error 77.301370 %
#      epoch 6, minibatch 659/659, test error of best model 77.023077 %
# epoch 7, minibatch 659/659, validation error 76.342466 %
#      epoch 7, minibatch 659/659, test error of best model 76.130769 %
# ...

# %%
import matplotlib.pyplot as plt
for i in range(0,8):
    #print 100 - test_performance_part4[i]*100
    #test_performance_part4[i] = test_performance_part4[i]
    print test_performance_part4[i]
# Out:
# 77.4192307692
# 79.5115384615
# 80.3384615385
# 82.2615384615
# 81.2269230769
# 81.1730769231
# 80.6538461538
# 81.3192307692

# %%
x = [1,2,3,4,5,6,7,8]
y = [77.4192307692 , 79.5115384615, 80.3384615385 , 82.2615384615, 81.2269230769, 81.1730769231, 80.6538461538, 81.3192307692]
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x,y)

plt.show()

# %% [markdown]
# Plot the result (reproducing Figure 2)

# %%
# TODO
test_performance_part4 = []
for i in range(1,9):
    test_per = test_mlp(layer = i, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.001, n_epochs=1000,
             batch_size=100, n_hidden=int (2400/i), verbose=True)
    test_performance_part4.append(test_per)
# Out:
# ... loading data
# ... building the model
# ... training

# %%
for i in range(0,8):
    test_performance_part4[i] = 100 - test_performance_part4[i]*100
    print test_performance_part4[i]
# Out:
# 78.1846153846
# 79.6923076923
# 82.4846153846
# 82.3461538462
# 82.6076923077
# 81.8615384615
# 80.95
# 81.3884615385

# %%
x4 = [1,2,3,4,5,6,7,8]

fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x4,test_performance_part4)

plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %%
# TODO

# %% [markdown]
# ### Bullet 5: Experiment with the number of neurons in hidden layers, but fix the number of hidden layers

# %%
# TODO
neurons = [250,500,750,1000,1250]
test_performance_part5a = []
for index in neurons:
    print index
    test_per = test_mlp(layer = 1, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.001, n_epochs=300,
             batch_size=100, n_hidden=index, verbose=True)
    test_performance_part5a.append(test_per)
# Out:
# 250
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 659/659, validation error 81.150685 %
#      epoch 1, minibatch 659/659, test error of best model 80.415385 %
# epoch 2, minibatch 659/659, validation error 80.972603 %
#      epoch 2, minibatch 659/659, test error of best model 80.315385 %
# epoch 3, minibatch 659/659, validation error 80.452055 %
#      epoch 3, minibatch 659/659, test error of best model 79.984615 %
# epoch 4, minibatch 659/659, validation error 80.013699 %
#      epoch 4, minibatch 659/659, test error of best model 79.630769 %
# epoch 5, minibatch 659/659, validation error 79.260274 %
#      epoch 5, minibatch 659/659, test error of best model 79.126923 %
# epoch 6, minibatch 659/659, validation error 78.547945 %
#      epoch 6, minibatch 659/659, test error of best model 78.430769 %
# epoch 7, minibatch 659/659, validation error 77.534247 %
#      epoch 7, minibatch 659/659, test error of best model 77.376923 %
# ...

# %% [markdown]
# Plot the result (reproducing Figure 3)

# %%
# TODO
x5a = [1,2,3,4,5]
#y5a = [77.4192307692 , 79.5115384615, 80.3384615385 , 82.2615384615, 81.2269230769, 81.1730769231, 80.6538461538, 81.3192307692]
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x5a,test_performance_part5a)

plt.show()

# %%
# TODO
neurons = [250,500,750,1000,1250]
test_performance_part5b = []
for index in neurons:
    print index
    test_per = test_mlp(layer = 2, act_function = 1, learning_rate=0.01, L1_reg=0.00, L2_reg=0.001, n_epochs=300,
             batch_size=100, n_hidden=index, verbose=True)
    test_performance_part5b.append(test_per)
# Out:
# 250
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 659/659, validation error 81.150685 %
#      epoch 1, minibatch 659/659, test error of best model 80.415385 %
# epoch 2, minibatch 659/659, validation error 81.136986 %
#      epoch 2, minibatch 659/659, test error of best model 80.415385 %
# epoch 3, minibatch 659/659, validation error 80.767123 %
#      epoch 3, minibatch 659/659, test error of best model 80.215385 %
# epoch 4, minibatch 659/659, validation error 80.287671 %
#      epoch 4, minibatch 659/659, test error of best model 79.903846 %
# epoch 5, minibatch 659/659, validation error 79.849315 %
#      epoch 5, minibatch 659/659, test error of best model 79.519231 %
# epoch 6, minibatch 659/659, validation error 79.383562 %
#      epoch 6, minibatch 659/659, test error of best model 79.030769 %
# epoch 7, minibatch 659/659, validation error 78.643836 %
#      epoch 7, minibatch 659/659, test error of best model 78.226923 %
# ...

# %%
for index in range(0,5):
    test_performance_part5b[index] = 100 - test_performance_part5b[index]*100
    print  test_performance_part5b[index]
# Out:
# 77.9730769231
# 79.2038461538
# 80.0461538462
# 80.5923076923
# 79.4884615385

# %%
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x5a,test_performance_part5b)

plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %%
# TODO
